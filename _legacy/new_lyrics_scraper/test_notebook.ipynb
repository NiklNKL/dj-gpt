# %%
from tor_controller import _get_html
from bs4 import BeautifulSoup

html = _get_html("https://www.azlyrics.com/a/a1.html")
soup = BeautifulSoup(html, 'html.parser')
# Out:
# ➡️ TOR-Request: https://www.azlyrics.com/a/a1.html
# ⏳ Warte 4.76s vor Request...
# 🔄 Neue Tor-Identität angefordert
# ✅ Erfolgreich geladen: https://www.azlyrics.com/a/a1.html

# %%
print(html)
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n<meta charset="utf-8">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\r\n<meta name="description" content="a1 lyrics - 88 song lyrics sorted by album, including &quot;Like A Rose&quot;, &quot;Everytime&quot;, &quot;Heaven By Your Side&quot;."> \r\n<meta name="keywords" content="a1, a1 lyrics, discography, albums, songs">\r\n<meta name="robots" content="noarchive">\r\n<title>a1 Lyrics</title>\r\n\r\n<link rel="canonical" href="https://www.azlyrics.com/a/a1.html" />\r\n<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.4/css/bootstrap.min.css">\r\n<link rel="stylesheet" href="/local/az.css">\r\n\r\n<!-- HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries -->\r\n<!--[if lt IE 9]>\r\n<script s
# ...

# %%
temp_list = soup.find("div", id="listAlbum")
print(temp_list)
# Out:
# <div id="listAlbum">
# <div class="album" id="99">album: <b>"Here We Come"</b> (1999)<div><img alt="a1 - Here We Come album cover" class="album-image" src="/images/albums/99/9c38160b669533368407304d88046f33.jpg"/></div></div>
# <div class="listalbum-item"><a href="/lyrics/a1/foreverinlove.html" target="_blank">Forever In Love</a></div>
# <div class="listalbum-item"><a href="/lyrics/a1/bethefirsttobelieve.html" target="_blank">Be The First To Believe</a></div>
# <div class="listalbum-item"><a href="/lyrics/a1/summertimeofourlives.html" target="_blank">Summertime Of Our Lives</a></div>
# <div class="listalbum-item"><a href="/lyrics/a1/readyornot.html" target="_blank">Ready Or Not</a></div>
# <div class="listalbum-item"><a href="/lyrics/a1/everytime.html" target="_blank">Everytime</a></div>
# <div class="listalbum-item"><a href="/lyrics/a1/ifonly.html" target="_blank">If Only</a></div>
# <div class="listalbum-item"><a href="/lyrics/a1/heyyou.html" target="_blank">Hey You</a></div>
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')
# Out:
# /tmp/ipykernel_30257/2699110942.py:2: MarkupResemblesLocatorWarning: The input passed in on this line looks more like a URL than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the web page found at a certain URL, then something has gone wrong. You should use an Python package like 'requests' to fetch the content behind the URL. Once you have the content as a string, you can feed that string into Beautiful Soup.
#
# However, if you want to parse some data that happens to look like a URL, then nothing has gone wrong: you are using Beautiful Soup correctly, and this warning is spurious and can be filtered. To make this warning go away, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import MarkupResemblesLocatorWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
#
#   soup = BeautifulSoup("https://www.azlyrics.com/a/a1.html", 'html.parser')

# %%
from scrape import scrape_letter

# z.B. alle Künstler mit A
temp = scrape_letter('a')

print(temp)
# Out:
# ➡️ TOR-Request: https://www.azlyrics.com/a.html
# ⏳ Warte 3.10s vor Request...
# 🔄 Neue Tor-Identität angefordert
# ⚠️ Versuch 1 fehlgeschlagen: 🚫 Möglicher Block durch Server
# 🔁 Backoff 2.44s...
# ⏳ Warte 2.14s vor Request...
# 🔄 Neue Tor-Identität angefordert
# ⚠️ Versuch 2 fehlgeschlagen: 🚫 Möglicher Block durch Server
# 🔁 Backoff 3.95s...
# ⏳ Warte 4.32s vor Request...
# 🔄 Neue Tor-Identität angefordert
# ⚠️ Versuch 3 fehlgeschlagen: 🚫 Möglicher Block durch Server
# 🔁 Backoff 4.69s...
# ❌ HTML konnte nicht geladen werden: https://www.azlyrics.com/a.html
# None

# %%
from stem.control import Controller
from stem import Signal
import os

# Auth-Cookie-Pfad aus deinem torrc (User-Modus)
cookie_path = os.path.expanduser('~/tor/data/control_auth_cookie')

with Controller.from_port(port=9051) as c:
    c.authenticate(cookie_path)
    c.signal(Signal.NEWNYM)
    print("🎉 Neue Identität erfolgreich angefordert!")
# Out:
# 🎉 Neue Identität erfolgreich angefordert!

# %%
{'origin': '185.56.83.83'}

# %%
import requests
from fake_useragent import UserAgent

proxies = {
    'http': 'socks5h://127.0.0.1:9050',
    'https': 'socks5h://127.0.0.1:9050'
}

headers = {'User-Agent': UserAgent().random}

response = requests.get("http://httpbin.org/ip", proxies=proxies, headers=headers)
print(response.json())
# Out:
# {'origin': '185.220.101.29'}
